# %%
# data frame dari hasil seleksi spreadsheet
# import modules
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
# data frame dari hasil seleksi spreadsheet

df = pd.read_clipboard()
df

# df = pd.read_clipboard()
# df
# Out:
#    #  df   =  pd.read_clipboard()
# 0  #  df NaN                  NaN
