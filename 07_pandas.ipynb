# %%
# import module
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
# persiapan data frame
## DEPRICATED ##
# df = pd.util.testing.makeMissingDataframe().reset_index() 
# df.head()

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 n_cols = 4
#       3 cols = ['A', 'B', 'C', 'D']
# ----> 5 df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)
#       7 nan_mask = np.random.rand(n_rows, n_cols) < 0.2
#       8 df[nan_mask] = np.nan
#
# NameError: name 'np' is not defined

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = df.rename(columns={'index':'Z'})
#       2 df.head()
#
# NameError: name 'df' is not defined

# %%
df_backup = df.copy(deep=True)

# %%
# menghapus (drop) setiap kolom mengandung missing values
df = df.dropna(axis='columns') 
df.head()

# %%
#menghapus setiap baris 
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()

# %%
# persentase missing values untuk setiap kolom
df = df_backup.copy(deep=True)
df.isna().mean()

# %%
# hapus setiap kolom yang mengandung mising values berdasarkan thershold
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
